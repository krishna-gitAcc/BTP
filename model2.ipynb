# %%
import numpy as np
import pandas as pd
import displacement_solver
import constitutive
import mesh_gen
import quadrature
import stress_gauss
import patch_n_int_nodes
import gauss_pt_coord
import stress_nodes_dc
import spr_stress

from sklearn.preprocessing import MinMaxScaler 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
from tensorflow.keras.models import model_from_json
# Out:
# 2023-04-28 14:37:27.231948: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-28 14:37:27.860885: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-28 14:37:29.989628: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-28 14:37:30.012442: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-28 14:37:37.531896: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# ............................Inputs Parameters......................#

#Doamin geometry
domain_coord = np.array([[2, 0], [20, 0], [20, 10], [0, 10], [0, 2]]);

# Body force components
b = np.array([[0], [0]])

# Traction Components
q = 1/8      #unirt force for unit length

T = np.array([[q, 0]]);

# Young's modulus
E = 1.0

# Poission's ration
nu = 1/3;

# problem type (0--->plane stress, 1---->plane strain)
problem_type = 0;

#Element type used for meshing (0---->4 nodes quadrilateral)
el_type = 0;

# No. of Gauss points required forintegration
ngp2d = 1;
ngp1d = 2;

# Number of mesh in one direction.
N = 5;

# %%
u = displacement_solver.solve_fem_plat_with_hole(N, E, nu, ngp2d, ngp1d, el_type, problem_type, domain_coord, b, T)
# print(u_node)

# %%
# ms = mesh size ----> Number of element in one direction
ms = N;

#total number of elements
nel = 2*ms*ms 

# reshaping u into u_nodes with displacement in x-direction in first column and y-direciton in second column
u_nodes = u.reshape((2*(ms+1)*(ms+1)-(ms+1), 2))
# print(u_nodes)

# %%
# constitutive relation matrix, calculated using the fuction "Constitutube" with input E->(Young's Modulus), nu(Poisson's raton), problem_type(plane stress or plane strain)
C = constitutive.constitutive(E, nu, problem_type)
# print(C);

# %%
# mesh generation 
nx = ms #number of element in x-direction
ny = ms #number of element in y-direction

# el_type = element type specifiedc. 0----> q4, q-----> q8, 2-----> q9
el_type = 0;

#mesh_obj = object created to calculated nodal coordinates ans connectivity array using functon "connectivity" and "coord_array" 
#input nx->number of element in x-direction, xy->number of element in y-direction, domain_coord->coordinates of the corner points and mid-points of the cook's skew beam problem, el_type->element type specidied.

mesh_obj = mesh_gen.platWithHole(nx, ny, domain_coord.reshape(10, 1), el_type);
connect = mesh_obj.connectivity();
# print(connect)
coord = mesh_obj.coord_array();

# %%
# from matplotlib import pyplot as plt
# xs = [x[0] for x in coord]
# ys = [x[1] for x in coord]
# plt.scatter(xs, ys)
# plt.show()

# %%
strs_ref = pd.read_csv('stress/spr/spr_ms_256.csv')
# strs_ref = strs_ref.abs()

# %%
# print(strs_ref)

# %%
X = pd.read_csv('Coord/mesh_256.csv')
X = X.loc[:, ~X.columns.str.contains('Unnamed')];
y = strs_ref;
y = y.loc[:, ~y.columns.str.contains('Unnamed')];
# y = y.loc[:, ~y.columns.str.contains('x')];
y = y.drop(columns=['x', 'y'])
# y = y.loc[:, ~y.columns.str.contains('y')];

# %%
# print(X.head())
# print(y.head())

# %%
scaler = MinMaxScaler()
scaler.fit(X)
scaled_x = scaler.transform(X)
scaled_test = scaler.transform(coord)
# Out:
# /home/krishna/Desktop/btp_499_code/btp_env/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
# print(X.head());
# print(scaled_x);
# print(scaled_test);
# print(len(scaled_x));
# print(len(scaled_test));

# %%
#ANN one model in whole domain
model1 = Sequential()
model1.add(Dense(units=50, activation='relu'))
model1.add(Dense(units=44, activation='relu'))
model1.add(Dense(units=37, activation='relu'))
model1.add(Dense(units=30, activation='relu'))
model1.add(Dense(units=24, activation='relu'))
model1.add(Dense(units=17, activation='relu'))
model1.add(Dense(units=10, activation='relu'))
model1.add(Dense(units=3, activation='relu'))
model1.add(Dense(units=3, activation='linear'))
model1.compile(
    loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.01))
# Out:
# 2023-04-28 14:38:56.811659: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
 es = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss',  mode = 'min', verbose = 1, patience = 50);
 np.random.seed(1)
 history = model1.fit(x = scaled_x, y = y, batch_size=256, epochs=300, verbose = 1, validation_split = 0.1, callbacks= [es]);
# Out:
# Epoch 1/300
# 464/464 [==============================] - 10s 9ms/step - loss: 0.1757 - val_loss: 0.3939
# Epoch 2/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0694 - val_loss: 0.3808
# Epoch 3/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0679 - val_loss: 0.3685
# Epoch 4/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0669 - val_loss: 0.2430
# Epoch 5/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0660 - val_loss: 0.2165
# Epoch 6/300
# 464/464 [==============================] - 3s 8ms/step - loss: 0.0654 - val_loss: 0.2956
# Epoch 7/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0659 - val_loss: 0.2396
# Epoch 8/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0653 - val_loss: 0.2283
# Epoch 9/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0638 - val_loss: 0.2202
# Epoch 10/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0610 - val_loss: 0.2146
# Epoch 11/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0613 - val_loss: 0.2363
# Epoch 12/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0619 - val_loss: 0.2462
# Epoch 13/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0606 - val_loss: 0.2426
# Epoch 14/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0601 - val_loss: 0.2741
# Epoch 15/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0594 - val_loss: 0.2798
# Epoch 16/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0605 - val_loss: 0.2543
# Epoch 17/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0603 - val_loss: 0.2300
# Epoch 18/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0597 - val_loss: 0.2887
# Epoch 19/300
# 464/464 [==============================] - 3s 8ms/step - loss: 0.0597 - val_loss: 0.2349
# Epoch 20/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0602 - val_loss: 0.2229
# Epoch 21/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0597 - val_loss: 0.2265
# Epoch 22/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0589 - val_loss: 0.2318
# Epoch 23/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0590 - val_loss: 0.2313
# Epoch 24/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0585 - val_loss: 0.2183
# Epoch 25/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0596 - val_loss: 0.2199
# Epoch 26/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0587 - val_loss: 0.2058
# Epoch 27/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0591 - val_loss: 0.2195
# Epoch 28/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0591 - val_loss: 0.2814
# Epoch 29/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0589 - val_loss: 0.2466
# Epoch 30/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0582 - val_loss: 0.2309
# Epoch 31/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0585 - val_loss: 0.2328
# Epoch 32/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0588 - val_loss: 0.2592
# Epoch 33/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0581 - val_loss: 0.2768
# Epoch 34/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0587 - val_loss: 0.2398
# Epoch 35/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0609 - val_loss: 0.2597
# Epoch 36/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0581 - val_loss: 0.2514
# Epoch 37/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0582 - val_loss: 0.2255
# Epoch 38/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0587 - val_loss: 0.2381
# Epoch 39/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0577 - val_loss: 0.2237
# Epoch 40/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0571 - val_loss: 0.2189
# Epoch 41/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0592 - val_loss: 0.2479
# Epoch 42/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0581 - val_loss: 0.2372
# Epoch 43/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0584 - val_loss: 0.2352
# Epoch 44/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0568 - val_loss: 0.2585
# Epoch 45/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0573 - val_loss: 0.2292
# Epoch 46/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0576 - val_loss: 0.2204
# Epoch 47/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0571 - val_loss: 0.2187
# Epoch 48/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0582 - val_loss: 0.2596
# Epoch 49/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0578 - val_loss: 0.2250
# Epoch 50/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0576 - val_loss: 0.2463
# Epoch 51/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0579 - val_loss: 0.2277
# Epoch 52/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0574 - val_loss: 0.2663
# Epoch 53/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0566 - val_loss: 0.2229
# Epoch 54/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0579 - val_loss: 0.2361
# Epoch 55/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0576 - val_loss: 0.2452
# Epoch 56/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0568 - val_loss: 0.2103
# Epoch 57/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0578 - val_loss: 0.2705
# Epoch 58/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0604 - val_loss: 0.2142
# Epoch 59/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0594 - val_loss: 0.2139
# Epoch 60/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0591 - val_loss: 0.2271
# Epoch 61/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0591 - val_loss: 0.2537
# Epoch 62/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0596 - val_loss: 0.2293
# Epoch 63/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0601 - val_loss: 0.2571
# Epoch 64/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0576 - val_loss: 0.2424
# Epoch 65/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0575 - val_loss: 0.2554
# Epoch 66/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0569 - val_loss: 0.2019
# Epoch 67/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0579 - val_loss: 0.1865
# Epoch 68/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0569 - val_loss: 0.2132
# Epoch 69/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0584 - val_loss: 0.2013
# Epoch 70/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0611 - val_loss: 0.2019
# Epoch 71/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0597 - val_loss: 0.1925
# Epoch 72/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0582 - val_loss: 0.2270
# Epoch 73/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0575 - val_loss: 0.1939
# Epoch 74/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0565 - val_loss: 0.2135
# Epoch 75/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0568 - val_loss: 0.2755
# Epoch 76/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0570 - val_loss: 0.2191
# Epoch 77/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0566 - val_loss: 0.2422
# Epoch 78/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0578 - val_loss: 0.1986
# Epoch 79/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0569 - val_loss: 0.2084
# Epoch 80/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0556 - val_loss: 0.2337
# Epoch 81/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0565 - val_loss: 0.1974
# Epoch 82/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0566 - val_loss: 0.2160
# Epoch 83/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0558 - val_loss: 0.1898
# Epoch 84/300
# 464/464 [==============================] - 4s 9ms/step - loss: 0.0558 - val_loss: 0.2284
# Epoch 85/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0571 - val_loss: 0.2093
# Epoch 86/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0563 - val_loss: 0.2546
# Epoch 87/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0561 - val_loss: 0.2132
# Epoch 88/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0573 - val_loss: 0.2033
# Epoch 89/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0563 - val_loss: 0.2215
# Epoch 90/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0568 - val_loss: 0.2453
# Epoch 91/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0573 - val_loss: 0.1969
# Epoch 92/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0566 - val_loss: 0.2401
# Epoch 93/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0564 - val_loss: 0.1976
# Epoch 94/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0564 - val_loss: 0.2303
# Epoch 95/300
# 464/464 [==============================] - 3s 8ms/step - loss: 0.0572 - val_loss: 0.1964
# Epoch 96/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0561 - val_loss: 0.1980
# Epoch 97/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0561 - val_loss: 0.2026
# Epoch 98/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0570 - val_loss: 0.1950
# Epoch 99/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0563 - val_loss: 0.1957
# Epoch 100/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0569 - val_loss: 0.2710
# Epoch 101/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0578 - val_loss: 0.2052
# Epoch 102/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0568 - val_loss: 0.2249
# Epoch 103/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0568 - val_loss: 0.1863
# Epoch 104/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0563 - val_loss: 0.2126
# Epoch 105/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0574 - val_loss: 0.2039
# Epoch 106/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0580 - val_loss: 0.2221
# Epoch 107/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0573 - val_loss: 0.2254
# Epoch 108/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0576 - val_loss: 0.2459
# Epoch 109/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0570 - val_loss: 0.1829
# Epoch 110/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0566 - val_loss: 0.3015
# Epoch 111/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0557 - val_loss: 0.2039
# Epoch 112/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0572 - val_loss: 0.1813
# Epoch 113/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0561 - val_loss: 0.3089
# Epoch 114/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0568 - val_loss: 0.2035
# Epoch 115/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0556 - val_loss: 0.2442
# Epoch 116/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0577 - val_loss: 0.2159
# Epoch 117/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0557 - val_loss: 0.2140
# Epoch 118/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0562 - val_loss: 0.1990
# Epoch 119/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0563 - val_loss: 0.2205
# Epoch 120/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0551 - val_loss: 0.2664
# Epoch 121/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0558 - val_loss: 0.2058
# Epoch 122/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0558 - val_loss: 0.1937
# Epoch 123/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0569 - val_loss: 0.1793
# Epoch 124/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0553 - val_loss: 0.2254
# Epoch 125/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0573 - val_loss: 0.1878
# Epoch 126/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0564 - val_loss: 0.2847
# Epoch 127/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0575 - val_loss: 0.2624
# Epoch 128/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0560 - val_loss: 0.1852
# Epoch 129/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0560 - val_loss: 0.2194
# Epoch 130/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0561 - val_loss: 0.2089
# Epoch 131/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0563 - val_loss: 0.2332
# Epoch 132/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0574 - val_loss: 0.1907
# Epoch 133/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0558 - val_loss: 0.2450
# Epoch 134/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0561 - val_loss: 0.2588
# Epoch 135/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0562 - val_loss: 0.2022
# Epoch 136/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0557 - val_loss: 0.1937
# Epoch 137/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0557 - val_loss: 0.2470
# Epoch 138/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0557 - val_loss: 0.2244
# Epoch 139/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0550 - val_loss: 0.1767
# Epoch 140/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0556 - val_loss: 0.1900
# Epoch 141/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0558 - val_loss: 0.1945
# Epoch 142/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0554 - val_loss: 0.2024
# Epoch 143/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0560 - val_loss: 0.2047
# Epoch 144/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0552 - val_loss: 0.2169
# Epoch 145/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0570 - val_loss: 0.1887
# Epoch 146/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0563 - val_loss: 0.2141
# Epoch 147/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0587 - val_loss: 0.2164
# Epoch 148/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0578 - val_loss: 0.2166
# Epoch 149/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0561 - val_loss: 0.1822
# Epoch 150/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0557 - val_loss: 0.2272
# Epoch 151/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0554 - val_loss: 0.2174
# Epoch 152/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0550 - val_loss: 0.2637
# Epoch 153/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0571 - val_loss: 0.1959
# Epoch 154/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0582 - val_loss: 0.1912
# Epoch 155/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0577 - val_loss: 0.2175
# Epoch 156/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0564 - val_loss: 0.1925
# Epoch 157/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0572 - val_loss: 0.1992
# Epoch 158/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0562 - val_loss: 0.2122
# Epoch 159/300
# 464/464 [==============================] - 3s 6ms/step - loss: 0.0564 - val_loss: 0.1992
# Epoch 160/300
# 464/464 [==============================] - 5s 10ms/step - loss: 0.0563 - val_loss: 0.2353
# Epoch 161/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0558 - val_loss: 0.1972
# Epoch 162/300
# 464/464 [==============================] - 4s 9ms/step - loss: 0.0564 - val_loss: 0.2306
# Epoch 163/300
# 464/464 [==============================] - 4s 9ms/step - loss: 0.0557 - val_loss: 0.2382
# Epoch 164/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0575 - val_loss: 0.1953
# Epoch 165/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0555 - val_loss: 0.1993
# Epoch 166/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0548 - val_loss: 0.2274
# Epoch 167/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0564 - val_loss: 0.1977
# Epoch 168/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0549 - val_loss: 0.2141
# Epoch 169/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0568 - val_loss: 0.2804
# Epoch 170/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0546 - val_loss: 0.2034
# Epoch 171/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0552 - val_loss: 0.2769
# Epoch 172/300
# 464/464 [==============================] - 4s 9ms/step - loss: 0.0555 - val_loss: 0.1951
# Epoch 173/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0571 - val_loss: 0.2415
# Epoch 174/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0543 - val_loss: 0.2044
# Epoch 175/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0558 - val_loss: 0.2449
# Epoch 176/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0561 - val_loss: 0.2208
# Epoch 177/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0563 - val_loss: 0.2021
# Epoch 178/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0559 - val_loss: 0.2958
# Epoch 179/300
# 464/464 [==============================] - 4s 9ms/step - loss: 0.0581 - val_loss: 0.1853
# Epoch 180/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0562 - val_loss: 0.2064
# Epoch 181/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0568 - val_loss: 0.2127
# Epoch 182/300
# 464/464 [==============================] - 3s 8ms/step - loss: 0.0558 - val_loss: 0.1928
# Epoch 183/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0575 - val_loss: 0.1870
# Epoch 184/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0554 - val_loss: 0.1766
# Epoch 185/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0551 - val_loss: 0.1953
# Epoch 186/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0565 - val_loss: 0.2234
# Epoch 187/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0551 - val_loss: 0.2206
# Epoch 188/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0558 - val_loss: 0.3243
# Epoch 189/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0572 - val_loss: 0.2268
# Epoch 190/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0574 - val_loss: 0.1884
# Epoch 191/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0606 - val_loss: 0.1855
# Epoch 192/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0588 - val_loss: 0.2515
# Epoch 193/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0585 - val_loss: 0.1923
# Epoch 194/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0580 - val_loss: 0.2808
# Epoch 195/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0609 - val_loss: 0.2426
# Epoch 196/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0581 - val_loss: 0.2530
# Epoch 197/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0575 - val_loss: 0.1976
# Epoch 198/300
# 464/464 [==============================] - 6s 12ms/step - loss: 0.0580 - val_loss: 0.2170
# Epoch 199/300
# 464/464 [==============================] - 5s 10ms/step - loss: 0.0577 - val_loss: 0.2559
# Epoch 200/300
# 464/464 [==============================] - 5s 10ms/step - loss: 0.0576 - val_loss: 0.2504
# Epoch 201/300
# 464/464 [==============================] - 5s 11ms/step - loss: 0.0577 - val_loss: 0.2181
# Epoch 202/300
# 464/464 [==============================] - 4s 9ms/step - loss: 0.0579 - val_loss: 0.1751
# Epoch 203/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0569 - val_loss: 0.2610
# Epoch 204/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0582 - val_loss: 0.1861
# Epoch 205/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0576 - val_loss: 0.2097
# Epoch 206/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0577 - val_loss: 0.2226
# Epoch 207/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0580 - val_loss: 0.2293
# Epoch 208/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0618 - val_loss: 0.1993
# Epoch 209/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0605 - val_loss: 0.2017
# Epoch 210/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0601 - val_loss: 0.2344
# Epoch 211/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0584 - val_loss: 0.2372
# Epoch 212/300
# 464/464 [==============================] - 3s 8ms/step - loss: 0.0584 - val_loss: 0.2509
# Epoch 213/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0619 - val_loss: 0.2083
# Epoch 214/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0583 - val_loss: 0.2718
# Epoch 215/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0572 - val_loss: 0.2242
# Epoch 216/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0571 - val_loss: 0.2148
# Epoch 217/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0613 - val_loss: 0.1933
# Epoch 218/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0576 - val_loss: 0.2336
# Epoch 219/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0585 - val_loss: 0.1839
# Epoch 220/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0585 - val_loss: 0.2273
# Epoch 221/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0581 - val_loss: 0.3902
# Epoch 222/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0578 - val_loss: 0.2307
# Epoch 223/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0579 - val_loss: 0.2291
# Epoch 224/300
# 464/464 [==============================] - 3s 8ms/step - loss: 0.0577 - val_loss: 0.2848
# Epoch 225/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0575 - val_loss: 0.1931
# Epoch 226/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0596 - val_loss: 0.1906
# Epoch 227/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0607 - val_loss: 0.1973
# Epoch 228/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0571 - val_loss: 0.2238
# Epoch 229/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0578 - val_loss: 0.2353
# Epoch 230/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0577 - val_loss: 0.2055
# Epoch 231/300
# 464/464 [==============================] - 4s 9ms/step - loss: 0.0576 - val_loss: 0.2179
# Epoch 232/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0578 - val_loss: 0.2592
# Epoch 233/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0592 - val_loss: 0.2005
# Epoch 234/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0573 - val_loss: 0.2177
# Epoch 235/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0573 - val_loss: 0.2108
# Epoch 236/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0587 - val_loss: 0.1937
# Epoch 237/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0592 - val_loss: 0.2069
# Epoch 238/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0596 - val_loss: 0.2060
# Epoch 239/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0580 - val_loss: 0.1871
# Epoch 240/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0572 - val_loss: 0.1821
# Epoch 241/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0576 - val_loss: 0.2318
# Epoch 242/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0578 - val_loss: 0.1867
# Epoch 243/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0588 - val_loss: 0.1926
# Epoch 244/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0566 - val_loss: 0.1945
# Epoch 245/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0578 - val_loss: 0.2405
# Epoch 246/300
# 464/464 [==============================] - 3s 7ms/step - loss: 0.0571 - val_loss: 0.2134
# Epoch 247/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0577 - val_loss: 0.1915
# Epoch 248/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0586 - val_loss: 0.2228
# Epoch 249/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0575 - val_loss: 0.2196
# Epoch 250/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0588 - val_loss: 0.1945
# Epoch 251/300
# 464/464 [==============================] - 4s 8ms/step - loss: 0.0588 - val_loss: 0.2079
# Epoch 252/300
# 464/464 [==============================] - 4s 9ms/step - loss: 0.0572 - val_loss: 0.2295
# Epoch 252: early stopping

# %%
var = 'x_y_xy'

# %%
loss = pd.DataFrame(model1.history.history);

# %%
# import matplotlib.pyplot as plt
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('train_loss', fontsize=15)
# plt.ylabel('Loss', fontsize=15)
# plt.xlabel('Epoch', fontsize=15)
# plt.legend(['train', 'val'], loc='upper right')
# plt.xticks(fontsize=15)
# plt.yticks(fontsize=15)
# plt.show()

# %%
#Saving train model with different optimizer.
model_json = model1.to_json()
with open('Model/model2_'+var+'.json', 'w') as json_file:
    json_file.write(model_json)

#serialize weights to HDF5 file
model1.save_weights('Model/model2_'+var+'.h5')

# %%
# # load json and create model
json_file = open('Model/model2_x_y_xy.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json);

# #load weights into new model
loaded_model.load_weights('Model/model2_x_y_xy.h5')

# %%
#Stress calculation at Gauss points
stress = np.zeros((nel, ngp2d*ngp2d, 3))
strains = np.zeros((nel, ngp2d*ngp2d, 3))

for i in range(nel):
    stress_i_g = np.zeros((ngp2d*ngp2d, 3))
    strains_i_g = np.zeros((ngp2d*ngp2d, 3))

    stress_i_g, strains_i_g = stress_gauss.get_element_stress(
        i, ngp2d, el_type, connect, coord, u, C)

    stress[i][:][:] = stress_i_g
    strains[i][:][:] = strains_i_g.reshape((1, 3))

# %%
# calcuation of gauss coordinates.
gauss_coords = np.zeros((nel, ngp2d*ngp2d, 2))
gp, weights = quadrature.quadrature(ngp2d)
for i in range(nel):
    node = connect[i, :]
    vertex_coord = coord[node, :].reshape(-1)
    gauss_coords[i][:][:] = gauss_pt_coord.gauss_pts(
        ngp2d, vertex_coord, gp, el_type)
gauss_coords = gauss_coords.reshape(gauss_coords.shape[0], -1)

# %%
#creation of patches for spr_stress;
patch, n_patches, int_nodes = patch_n_int_nodes.patch_n_int_nodes_plat_with_hole(ms)

# %%
#spr_stress STRESS Calculations
stress_spr = spr_stress.spr_plat_with_hole(gauss_coords, coord, connect, stress,
                     int_nodes, n_patches, patch, ms)
# stress_spr

# %%
#Directly calculated stress
stress_dc, strain_dc = stress_nodes_dc.stress_dc(
    connect, coord, u, nel, el_type, C);

# %%
#outter points in
sp = []
# print(ms)
# ms = 4
temp = ms+1
for i in range(2*ms-1):
    sp.append(temp)
    sp.append(temp+ms)
    temp = temp+ms+1
for i in range(ms+1):
    sp.append(temp)
    temp = temp+1

for i in range(ms+1):
    sp.append(i)

sp = sorted(sp)
# print(sp);

# %%
coord_corner = coord[sp]
# print(coord_corner)

# %%
scaled_test_corner = scaler.transform(coord_corner)
# scaled_test_corner
# Out:
# /home/krishna/Desktop/btp_499_code/btp_env/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
ref_stress = pd.read_csv('ref_stress/ref_stress_for_ms_5_from_320.csv');
ref_stress = ref_stress.loc[:, ~ref_stress.columns.str.contains('^Unnamed')];
ref_stress = ref_stress.drop(columns=['x', 'y'])
# print(ref_stress)

ref_stress = ref_stress.to_numpy();
# ref_stress

# %%
a = ref_stress.T
# print(len(a));

# %%
b = stress_spr.T
# print(len(b))

# %%
err_spr_abs = np.abs((a-b));
err_spr_perc = np.abs((a-b)/a);
err_dc_abs = np.abs((a-stress_dc.T));
err_dc_perc = np.abs((a-stress_dc.T)/a);
# err_spr_abs
# err_dc_abs

# %%
test = pd.DataFrame(scaled_test, columns =['a', 'b']);
# test

# %%
c = loaded_model.predict(test);
# len(c)
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %%
err_ann_abs = np.abs((a-c.T))
err_ann_perc = np.abs((a-c.T)/a)
# err_ann_abs

# %%
alll = np.concatenate([coord, 
                        a.reshape(a.T.shape[0], 3), 
                        b.reshape(b.T.shape[0], 3), 
                        c.reshape(c.shape[0], 3), 
                        err_spr_abs.reshape(err_spr_abs.T.shape[0], 3), 
                        err_ann_abs.reshape(err_ann_abs.T.shape[0],3), 
                        err_dc_abs.reshape(err_dc_abs.T.shape[0],3),
                        err_spr_perc.reshape(err_spr_perc.T.shape[0],3),
                        err_ann_perc.reshape(err_ann_perc.T.shape[0],3),
                        err_dc_perc.reshape(err_dc_perc.T.shape[0],3) 
                        ], 
                        axis = 1);
# alll

# %%
tdf =pd.DataFrame(alll, columns=['x', 
                                'y', 
                                'ref_stress_x',
                                'ref_stress_y',
                                'ref_stress_xy', 
                                'spr_stress_x',
                                'spr_stress_y',
                                'spr_stress_xy', 
                                'ann_stress_x',
                                'ann_stress_y',
                                'ann_stress_xy', 
                                'err_spr_abs_x',
                                'err_spr_abs_y',
                                'err_spr_abs_xy', 
                                'err_ann_abs_x',
                                'err_ann_abs_y',
                                'err_ann_abs_xy', 
                                'err_dc_abs_x',
                                'err_dc_abs_y',
                                'err_dc_abs_xy',
                                'err_spr_perc_x',
                                'err_spr_perc_y',
                                'err_spr_perc_xy', 
                                'err_ann_perc_x',
                                'err_ann_perc_y',
                                'err_ann_perc_xy', 
                                'err_dc_perc_x',
                                'err_dc_perc_y',
                                'err_dc_perc_xy'
                                ]);
# print(tdf);

# %%
tdf.to_csv('Results/all_matlab_train_model2_ref_'+var+'.csv');
tdf.head()
# Out:
#       x    y  ref_stress_x  ref_stress_y  ref_stress_xy  spr_stress_x  \
# 0   2.0  0.0     -0.000173      0.144666      -9.529965     -0.977762
# 1   5.6  0.0      7.839685      2.178640       2.840977     -0.072839
# 2   9.2  0.0     -0.000071    -91.354094    -251.462422     -0.687458
# 3  12.8  0.0     13.157520      5.933357       1.333309     -0.303101
# 4  16.4  0.0      0.000929  -3946.754606  -10292.325574     -0.482481
#
#    spr_stress_y  spr_stress_xy  ann_stress_x  ann_stress_y  ...  \
# 0     -0.694206      -0.216256      0.034613     -0.002147  ...
# 1     -0.037187       0.069772      0.034613     -0.002147  ...
# 2     -1.050563      -0.762537      0.034613     -0.002147  ...
# 3     -0.069180       0.015766      0.034613     -0.002147  ...
# 4     -1.214000      -0.727692      0.034613     -0.002147  ...
#
#    err_dc_abs_xy  err_spr_perc_x  err_spr_perc_y  err_spr_perc_xy  \
# 0      10.428038     5663.061093        5.798695         0.977308
# 1       3.660670        1.009291        1.017069         0.975441
# 2     249.095729     9701.518261        0.988500         0.996968
# 3       0.261244        1.023036        1.011660         0.988175
# 4   10293.383032      520.619879        0.999692         0.999929
#
#    err_ann_perc_x  err_ann_perc_y  err_ann_perc_xy  err_dc_perc_x  \
# 0      201.510531        0.760736         1.003632   61341.118638
# 1        0.995585        0.984112         0.987816       1.164220
# 2      489.518237        1.000379         1.000138  173905.116993
# 3        0.997369        0.994166         0.974040       0.955942
# 4       36.277566        1.000009         1.000003    9889.297830
#
#    err_dc_perc_y  err_dc_perc_xy
# 0      27.907634        1.094237
# 1       0.844558        1.288525
# 2       1.021424        0.990588
# 3       1.091159        0.195937
# 4       0.998992        1.000103
#
# [5 rows x 29 columns]
